# %%
d = {"key":"value","key1":"value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox

# %%
d2 = {"key":"value","key1":"value1"}

# %%
d2 = {"key":"value","key1":"value1"}

# %%
d2 = ConfigBox(d2)

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key1
# Out:
# 'value1'

# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x=2, y=3)
# Out:
# 6

# %%
get_product(x=2, y="3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x=2, y=3)
# Out:
# 6

# %% [markdown]
# Download data from google drive

# %%
import sys
print(sys.executable)
# Out:
# /opt/anaconda3/envs/chestmlops/bin/python

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/15kPbkluEGLCd2taIBJ-0t7Fwzqh5BCVt/view?usp=sharing"

# %%
type(url)
# Out:
# str

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '15kPbkluEGLCd2taIBJ-0t7Fwzqh5BCVt'

# %%
file_id = url.split("/")[-1]
file_id
# Out:
# '18q3OBP809T-1gan7uk0-A506s89agf0P?usp=sharing'

# %%
import gdown
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=15kPbkluEGLCd2taIBJ-0t7Fwzqh5BCVt
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=15kPbkluEGLCd2taIBJ-0t7Fwzqh5BCVt&confirm=t&uuid=12819a70-b4fb-46cb-bf68-5d3ec3748541
# To: /Users/srishtisingh/chest-cancer-classification-mlops/research/Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:04<00:00, 11.1MB/s]
# 'Chest-CT-Scan-data.zip'
